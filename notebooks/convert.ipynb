# %% [markdown]
# # ヒグマ出没データのCSVデータをもとに、geojson形式に変換するノートブック
#
# 出典：[札幌市オープンデータ「熊の出没情報」](https://ckan.pf-sapporo.jp/dataset/sapporo_bear_appearance)
#
# 当該データは [クリエイティブ・コモンズ 表示 4.0 国際ライセンス（CC BY 4.0）](https://creativecommons.org/licenses/by/4.0/deed.ja) の下で提供されています。
#
# © 札幌市, CC BY 4.0

# %% [markdown]
# # 定数定義

# %%
CSV_DIR = './data/csv'
GEOJSON_DIR = './data/geojson'
GEOJSON_FILE = 'bears.geojson'

# %% [markdown]
# # 必要ライブラリのインポート

# %%
import os
import pandas as pd
import geojson

# %% [markdown]
# # CSV読み取り

# %%
csv_files: list[str] = []
files = os.listdir(CSV_DIR)
for file in files:
    if file.endswith('.csv'):
        csv_files.append(file)

# %%
csv_files.sort()

# %%
csv_files

# %%
df: pd.DataFrame = pd.DataFrame()
for file in csv_files:
    tmp = pd.read_csv('{}/{}'.format(CSV_DIR, file,), encoding='utf8')
    df = pd.concat([df,tmp])

# %%
df

# %%
# for row in df.iterrows():
#     for col in row:
#         print(col)
